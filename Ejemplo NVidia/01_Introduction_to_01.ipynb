# %% [markdown]
# # Introduction to Lab 1 Notebook 1

# %% [markdown]
# Execute the following cell to load slides for this part of the workshop. After loading, if you wish, you can click on the "Slide Show" icon at the bottom right of the slide to see the slides in fullscreen.

# %%
from IPython.display import IFrame
IFrame('https://view.officeapps.live.com/op/view.aspx?src=https://developer.download.nvidia.com/training/courses/C-MG-01-V2/slides/v2.0/01/01_Introduction_to_Lab_1_Notebook_1.pptx', 700, 500)
# Out:
#         <iframe
#             width="700"
#             height="500"
#             src="https://view.officeapps.live.com/op/view.aspx?src=https://developer.download.nvidia.com/training/courses/C-MG-01-V2/slides/v2.0/01/01_Introduction_to_Lab_1_Notebook_1.pptx"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
