# %% [markdown]
# # Introduction to Lab 1 Notebook 2

# %% [markdown]
# Execute the following cell to load slides for this part of the workshop. After loading, if you wish, you can click on the "Slide Show" icon at the bottom right of the slide to see the slides in fullscreen.

# %%
from IPython.display import IFrame
IFrame('https://view.officeapps.live.com/op/view.aspx?src=https://developer.download.nvidia.com/training/courses/C-MG-01-V2/slides/v2.0/01/02_Introduction_to_Lab_1_Notebook_2.pptx', 700, 500)
